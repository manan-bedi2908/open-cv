# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import cv2

# %%
pil = Image.open('Thor.jpg')

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
cut = arr[:5, :5]

# %%
cut
# Out:
# array([[[67, 68, 60],
#         [67, 68, 60],
#         [68, 69, 61],
#         [68, 69, 61],
#         [68, 69, 61]],
#
#        [[66, 67, 59],
#         [67, 68, 60],
#         [67, 68, 60],
#         [67, 68, 60],
#         [68, 69, 61]],
#
#        [[66, 67, 59],
#         [66, 67, 59],
#         [67, 68, 60],
#         [67, 68, 60],
#         [67, 68, 60]],
#
#        [[67, 68, 60],
#         [67, 68, 60],
#         [68, 69, 61],
#         [68, 69, 61],
#         [69, 70, 62]],
#
#        [[69, 70, 62],
#         [69, 70, 62],
#         [70, 71, 63],
#         [70, 71, 63],
#         [71, 72, 64]]], dtype=uint8)

# %%
plt.imshow(cut)

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]] = 0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray, cmap='gray')
